# %%
library(ggplot2)
ages <- c(19, 20, 19, 21)
budgets <- c(0, 0, 0, 1)
qplot(ages, budgets) + stat_smooth(method="lm", level=0.95) + theme_bw(base_size=18)
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
library(MASS)
library(data.table)
means <- data.table(genotype)[,.(Wt.Mean=mean(Wt)), by=Litter]
barplot(
    means$Wt.Mean,
    names.arg=c("а", "b", "i", "j"),
    col=c("deepskyblue1", "firebrick1", "chartreuse1", "darkorchid1"),
    legend=means$Litter
)
# Out:
# plot without title
